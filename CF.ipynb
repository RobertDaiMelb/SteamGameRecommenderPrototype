# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("drive/MyDrive/9727/steam_reviews.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'app_id', 'app_name', 'review_id', 'language',
#        'timestamp_created', 'timestamp_updated', 'recommended',
#        'votes_helpful', 'votes_funny', 'weighted_vote_score', 'comment_count',
#        'steam_purchase', 'received_for_free', 'written_during_early_access',
#        'author.steamid', 'author.num_games_owned', 'author.num_reviews',
#        'author.playtime_forever', 'author.playtime_last_two_weeks',
#        'author.playtime_at_review', 'author.last_played', 'id'],
#       dtype='object')

# %%
df['author.steamid'].nunique()
# Out:
# 12406560

# %%
# Count number of reviews for each user
df_count = df['author.steamid'].value_counts().to_frame().reset_index().rename(columns={'author.steamid': 'count'})

# %%
df_count.query("count >= 10")
# Out:
#                     index  count
# 0       76561198062813911    149
# 1       76561198315585536    132
# 2       76561198192166873    107
# 3       76561198239163744    106
# 4       76561198045381877    103
# ...                   ...    ...
# 119479  76561198134530251     10
# 119480  76561197982171292     10
# 119481  76561198189593293     10
# 119482  76561198255402392     10
# 119483  76561198068439332     10
#
# [119484 rows x 2 columns]

# %%
# Sampling: only reserve users who made more than 10 reviews
new_df = df.loc[df['author.steamid'].isin(df_count.query("count >= 10")['index'].values), :]

# %%
new_df.shape
# Out:
# (1693064, 23)

# %%
# Generate users-items matrix
u_a_df = new_df.pivot_table(index='author.steamid', columns='app_id', values='recommended')

# %%
u_a_df.head()
# Out:
# app_id             70       240      420      620      2870     4000     \
# author.steamid
# 76561197960269230      1.0      NaN      NaN      NaN      NaN      NaN
# 76561197960269294      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960269409      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960270613      NaN      1.0      NaN      NaN      NaN      NaN
# 76561197960271099      NaN      NaN      NaN      1.0      NaN      NaN
#
# app_id             7510     8870     8930     32470    ...  1158310  1170880  \
# author.steamid                                         ...
# 76561197960269230      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960269294      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960269409      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960270613      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960271099      NaN      NaN      NaN      NaN  ...      NaN      NaN
#
# app_id             1180380  1190460  1222700  1225330  1229490  1240210  \
# author.steamid
# 76561197960269230      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960269294      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960269409      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960270613      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960271099      NaN      NaN      NaN      NaN      NaN      NaN
#
# app_id             1289310  1291340
# author.steamid
# 76561197960269230      NaN      NaN
# 76561197960269294      NaN      NaN
# 76561197960269409      NaN      NaN
# 76561197960270613      NaN      NaN
# 76561197960271099      NaN      NaN
#
# [5 rows x 315 columns]

# %%
new_df.loc[df['author.steamid'] == 76561198062813911, :]
# Out:
#           Unnamed: 0  app_id                  app_name  review_id language  \
# 512675        512676      70                 Half-Life   29251440  english
# 539037        539038     240    Counter-Strike: Source   71899643  english
# 658130        658131     420  Half-Life 2: Episode Two   37036842  english
# 849477        849478     620                  Portal 2   17866117  english
# 1549581      1549582    4000               Garry's Mod    6281334  english
# ...              ...     ...                       ...        ...      ...
# 21578107    21578112  367520             Hollow Knight   44704056  english
# 21624890    21624895  447820             Day of Infamy   32070388  english
# 21651066    21651071  598330                SimAirport   30840789  english
# 21656340    21656345  543460             Dead Rising 4   68516852  english
# 21672218    21672223  355790  Styx: Shards of Darkness   35024623  english
#
#           timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 512675           1484411669         1484411669         True              0
# 539037           1593717565         1593717565         True              0
# 658130           1511438724         1511438744         True              1
# 849477           1441305015         1441305258         True              0
# 1549581          1374488725         1418986129         True              1
# ...                     ...                ...          ...            ...
# 21578107         1536788275         1536788275         True              0
# 21624890         1496174428         1496174428         True              0
# 21651066         1490906109         1490906109         True              0
# 21656340         1588540484         1588540491         True              1
# 21672218         1505657932         1511430359         True             11
#
#           votes_funny  ...  received_for_free  written_during_early_access  \
# 512675              0  ...              False                        False
# 539037              0  ...              False                        False
# 658130              0  ...              False                        False
# 849477              0  ...              False                        False
# 1549581             0  ...              False                        False
# ...               ...  ...                ...                          ...
# 21578107            0  ...              False                        False
# 21624890            0  ...              False                        False
# 21651066            0  ...              False                         True
# 21656340            0  ...              False                        False
# 21672218            2  ...              False                        False
#
#              author.steamid  author.num_games_owned  author.num_reviews  \
# 512675    76561198062813911                    1584                1621
# 539037    76561198062813911                    1584                1621
# 658130    76561198062813911                    1584                1621
# 849477    76561198062813911                    1584                1621
# 1549581   76561198062813911                    1584                1621
# ...                     ...                     ...                 ...
# 21578107  76561198062813911                    1584                1621
# 21624890  76561198062813911                    1584                1621
# 21651066  76561198062813911                    1584                1621
# 21656340  76561198062813911                    1584                1621
# 21672218  76561198062813911                    1584                1621
#
#           author.playtime_forever  author.playtime_last_two_weeks  \
# 512675                      792.0                             0.0
# 539037                      370.0                             0.0
# 658130                      260.0                             0.0
# 849477                      392.0                             0.0
# 1549581                    2647.0                             0.0
# ...                           ...                             ...
# 21578107                    209.0                             0.0
# 21624890                    581.0                             0.0
# 21651066                   2844.0                             1.0
# 21656340                    626.0                             0.0
# 21672218                    764.0                             0.0
#
#           author.playtime_at_review  author.last_played      id
# 512675                        790.0        1.520431e+09      70
# 539037                        370.0        1.593717e+09     240
# 658130                        260.0        1.511436e+09     420
# 849477                        392.0        1.441297e+09     620
# 1549581                      2429.0        1.419871e+09    4000
# ...                             ...                 ...     ...
# 21578107                      209.0        1.536247e+09  367520
# 21624890                      581.0        1.496174e+09  447820
# 21651066                      958.0        1.610829e+09  598330
# 21656340                      626.0        1.588522e+09  543460
# 21672218                      764.0        1.505657e+09  355790
#
# [149 rows x 23 columns]

# %%
new_df.loc[(new_df['steam_purchase'] == True) & (new_df['received_for_free'] == True), :].head(3)
# Out:
#        Unnamed: 0  app_id                  app_name  review_id  language  \
# 12084       12084  292030  The Witcher 3: Wild Hunt   83324961   english
# 13718       13718  292030  The Witcher 3: Wild Hunt   83103321   russian
# 17615       17615  292030  The Witcher 3: Wild Hunt   82542331  schinese
#
#        timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 12084         1609099045         1609099045         True              0
# 13718         1608892460         1608892460         True              1
# 17615         1608186554         1608186554         True            972
#
#        votes_funny  ...  received_for_free  written_during_early_access  \
# 12084            2  ...               True                        False
# 13718            1  ...               True                        False
# 17615           71  ...               True                        False
#
#           author.steamid  author.num_games_owned  author.num_reviews  \
# 12084  76561198302463343                      28                  23
# 13718  76561198052888970                      72                  67
# 17615  76561198240308814                     191                  33
#
#        author.playtime_forever  author.playtime_last_two_weeks  \
# 12084                    331.0                             0.0
# 13718                    447.0                            53.0
# 17615                    696.0                             0.0
#
#        author.playtime_at_review  author.last_played      id
# 12084                      126.0        1.609274e+09  292030
# 13718                      206.0        1.611118e+09  292030
# 17615                      696.0        1.591345e+09  292030
#
# [3 rows x 23 columns]

# %%
new_df.loc[(new_df['steam_purchase'] == True) & (new_df['received_for_free'] == False), :].head(3)
# Out:
#     Unnamed: 0  app_id                  app_name  review_id  language  \
# 39          39  292030  The Witcher 3: Wild Hunt   85174926   english
# 47          47  292030  The Witcher 3: Wild Hunt   85172618   turkish
# 76          76  292030  The Witcher 3: Wild Hunt   85165570  schinese
#
#     timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 39         1611364401         1611364470         True              0
# 47         1611360594         1611360594         True              0
# 76         1611350390         1611350390         True              0
#
#     votes_funny  ...  received_for_free  written_during_early_access  \
# 39            0  ...              False                        False
# 47            0  ...              False                        False
# 76            0  ...              False                        False
#
#        author.steamid  author.num_games_owned  author.num_reviews  \
# 39  76561198020027165                     208                 105
# 47  76561198246626952                     206                  26
# 76  76561198220195440                     168                  56
#
#     author.playtime_forever  author.playtime_last_two_weeks  \
# 39                    497.0                           370.0
# 47                   3929.0                            41.0
# 76                   4988.0                           250.0
#
#     author.playtime_at_review  author.last_played      id
# 39                      398.0        1.611370e+09  292030
# 47                     3929.0        1.610813e+09  292030
# 76                     4737.0        1.611367e+09  292030
#
# [3 rows x 23 columns]

# %%
new_df.loc[(new_df['steam_purchase'] == False) & (new_df['received_for_free'] == True), :].head(3)
# Out:
#       Unnamed: 0  app_id                  app_name  review_id language  \
# 4129        4129  292030  The Witcher 3: Wild Hunt   84447402  russian
# 4949        4949  292030  The Witcher 3: Wild Hunt   84330747  russian
# 7510        7510  292030  The Witcher 3: Wild Hunt   83968159  russian
#
#       timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 4129         1610305316         1610305316        False              5
# 4949         1610159686         1610159686         True              1
# 7510         1609743028         1609743028         True              0
#
#       votes_funny  ...  received_for_free  written_during_early_access  \
# 4129            0  ...               True                        False
# 4949            0  ...               True                        False
# 7510            0  ...               True                        False
#
#          author.steamid  author.num_games_owned  author.num_reviews  \
# 4129  76561198253363352                     268                 101
# 4949  76561198398141804                      33                  12
# 7510  76561198306008357                      68                  36
#
#       author.playtime_forever  author.playtime_last_two_weeks  \
# 4129                    160.0                             0.0
# 4949                  10253.0                          5429.0
# 7510                   6208.0                          1255.0
#
#       author.playtime_at_review  author.last_played      id
# 4129                      160.0        1.607953e+09  292030
# 4949                     4504.0        1.611308e+09  292030
# 7510                     3982.0        1.610652e+09  292030
#
# [3 rows x 23 columns]

# %%
new_df.loc[(new_df['steam_purchase'] == False) & (new_df['received_for_free'] == False), :].head(3)
# Out:
#      Unnamed: 0  app_id                  app_name  review_id  language  \
# 41           41  292030  The Witcher 3: Wild Hunt   85173767   turkish
# 146         146  292030  The Witcher 3: Wild Hunt   85153647   russian
# 321         321  292030  The Witcher 3: Wild Hunt   85122164  schinese
#
#      timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 41          1611362536         1611364881         True              0
# 146         1611335171         1611335171        False              1
# 321         1611286912         1611286912         True              0
#
#      votes_funny  ...  received_for_free  written_during_early_access  \
# 41             0  ...              False                        False
# 146            0  ...              False                        False
# 321            0  ...              False                        False
#
#         author.steamid  author.num_games_owned  author.num_reviews  \
# 41   76561198316530785                     217                  34
# 146  76561198344619208                      70                  24
# 321  76561198277218887                     272                  18
#
#      author.playtime_forever  author.playtime_last_two_weeks  \
# 41                    6841.0                          2077.0
# 146                    279.0                           135.0
# 321                    682.0                             0.0
#
#      author.playtime_at_review  author.last_played      id
# 41                      6841.0        1.611364e+09  292030
# 146                      261.0        1.611336e+09  292030
# 321                      682.0        1.607052e+09  292030
#
# [3 rows x 23 columns]

# %%
# credibility : {timestamp_updated: Review latest update timestamp
#         votes_helpful: Number of "helpful" votes for review
#         votes_funny: Number of "funny" votes for review
#         steam_purchase: Whether review author purchased the app on Steam
#         written_during_early_access: Whether review was written during early access
#         author.playtime_at_review: Author playtime of reviewed app at time of review}

# %%
import bisect

def credibility(user_id, app_id, df):

  def rank(sorted_list, value):
    # bisect_left function returns the index of the inserted value, which is the point that can be inserted while keeping the list sorted
    index = bisect.bisect_left(sorted_list, value)
    # Check if the index is in the range of the list and if the value of the list at the index is equal to the value we are looking for
    if index != len(sorted_list) and sorted_list[index] == value:
        return index + 1
    return -1

  def give_vote_score():
    vote_helpful = df.loc[(df['author.steamid'] == user_id) & (df['app_id'] == app_id), 'votes_helpful'].values[0]
    vote_funny = df.loc[(df['author.steamid'] == user_id) & (df['app_id'] == app_id), 'votes_funny'].values[0]
    if vote_helpful == 0:
      vote_score = 1
    elif 0 < vote_helpful < 10:
      vote_score = 2
    elif 10 <= vote_helpful < 50:
      vote_score = 3
    elif 50 <= vote_helpful < 100:
      vote_score = 4
    elif vote_helpful >= 100:
      vote_score = 5
    if vote_funny >= 10:
      vote_score += 1
    return vote_score
  def give_time_score():
    play_time = df.loc[(df['author.steamid'] == user_id) & (df['app_id'] == app_id), 'author.playtime_at_review'].values[0]
    if play_time < 100:
      time_score = 1
    elif 100 <= play_time < 500:
      time_score = 2
    elif 500 <= play_time < 1000:
      time_score = 3
    elif play_time >= 1000:
      time_score = 4
    return time_score
  # Base score
  Base_score = give_vote_score() + give_time_score()
  print(Base_score)
  # timestamp_updated
  timestamp = df.loc[df['app_id'] == app_id, 'timestamp_updated'].sort_values().values.tolist()
    # Bigger timestamp implies newer review
  user_timestamp = df.loc[(df['app_id'] == app_id) & (df['author.steamid'] == user_id), 'timestamp_updated'].values[0]
  rank = rank(timestamp, user_timestamp)
  newest_per = rank / len(timestamp)
  score = Base_score * newest_per
  # steam_purchase
  if df.loc[(df['author.steamid'] == user_id) & (df['app_id'] == app_id), 'steam_purchase'].values[0] == False:
    score *= 0.5
  # written_during_early_access
  if df.loc[(df['author.steamid'] == user_id) & (df['app_id'] == app_id), 'written_during_early_access'].values[0] == True:
    score *= 0.5

  return round(score, 2)

# %%
u_a_df.head(1000).T.corr()
# Out:
# author.steamid     76561197960269230  76561197960269294  76561197960269409  \
# author.steamid
# 76561197960269230                1.0                NaN                NaN
# 76561197960269294                NaN                NaN                NaN
# 76561197960269409                NaN                NaN                1.0
# 76561197960270613                NaN                NaN                NaN
# 76561197960271099                NaN                NaN                NaN
# ...                              ...                ...                ...
# 76561197964410359                NaN                NaN                NaN
# 76561197964416237                NaN                NaN                NaN
# 76561197964416860                NaN                NaN                NaN
# 76561197964419684                NaN                NaN                NaN
# 76561197964431051                NaN                NaN                NaN
#
# author.steamid     76561197960270613  76561197960271099  76561197960271994  \
# author.steamid
# 76561197960269230                NaN                NaN                NaN
# 76561197960269294                NaN                NaN                NaN
# 76561197960269409                NaN                NaN                NaN
# 76561197960270613                1.0                NaN                NaN
# 76561197960271099                NaN           1.000000           0.448543
# ...                              ...                ...                ...
# 76561197964410359                NaN                NaN                NaN
# 76561197964416237                NaN                NaN                NaN
# 76561197964416860                NaN                NaN           0.632456
# 76561197964419684                NaN           0.333333           1.000000
# 76561197964431051                0.5          -0.577350          -0.447214
#
# author.steamid     76561197960272328  76561197960272871  76561197960275167  \
# author.steamid
# 76561197960269230                NaN                NaN                NaN
# 76561197960269294                NaN                NaN                NaN
# 76561197960269409                NaN                NaN                NaN
# 76561197960270613                NaN                NaN                NaN
# 76561197960271099                NaN                1.0                NaN
# ...                              ...                ...                ...
# 76561197964410359                NaN                NaN                NaN
# 76561197964416237                NaN                NaN                NaN
# 76561197964416860                NaN                NaN                NaN
# 76561197964419684                NaN                NaN                NaN
# 76561197964431051                NaN                NaN                NaN
#
# author.steamid     76561197960275345  ...  76561197964364124  \
# author.steamid                        ...
# 76561197960269230                NaN  ...                NaN
# 76561197960269294                NaN  ...                NaN
# 76561197960269409                NaN  ...                NaN
# 76561197960270613                NaN  ...                NaN
# 76561197960271099                NaN  ...                NaN
# ...                              ...  ...                ...
# 76561197964410359                NaN  ...                NaN
# 76561197964416237                NaN  ...                NaN
# 76561197964416860                NaN  ...                NaN
# 76561197964419684                NaN  ...                NaN
# 76561197964431051                NaN  ...                NaN
#
# author.steamid     76561197964373912  76561197964390992  76561197964401194  \
# author.steamid
# 76561197960269230                NaN                NaN                NaN
# 76561197960269294                NaN                NaN                NaN
# 76561197960269409                NaN                NaN                NaN
# 76561197960270613                NaN                NaN                NaN
# 76561197960271099                NaN                NaN                NaN
# ...                              ...                ...                ...
# 76561197964410359                NaN                NaN                NaN
# 76561197964416237                NaN                NaN                NaN
# 76561197964416860                NaN                NaN                NaN
# 76561197964419684                NaN                NaN                NaN
# 76561197964431051                NaN                NaN                NaN
#
# author.steamid     76561197964403737  76561197964410359  76561197964416237  \
# author.steamid
# 76561197960269230                NaN                NaN                NaN
# 76561197960269294                NaN                NaN                NaN
# 76561197960269409                NaN                NaN                NaN
# 76561197960270613                NaN                NaN                NaN
# 76561197960271099                NaN                NaN                NaN
# ...                              ...                ...                ...
# 76561197964410359                NaN                1.0                NaN
# 76561197964416237                NaN                NaN                NaN
# 76561197964416860                NaN                NaN                NaN
# 76561197964419684                NaN                NaN                NaN
# 76561197964431051                NaN                NaN                NaN
#
# author.steamid     76561197964416860  76561197964419684  76561197964431051
# author.steamid
# 76561197960269230                NaN                NaN                NaN
# 76561197960269294                NaN                NaN                NaN
# 76561197960269409                NaN                NaN                NaN
# 76561197960270613                NaN                NaN            0.50000
# 76561197960271099                NaN           0.333333           -0.57735
# ...                              ...                ...                ...
# 76561197964410359                NaN                NaN                NaN
# 76561197964416237                NaN                NaN                NaN
# 76561197964416860                1.0                NaN                NaN
# 76561197964419684                NaN           1.000000                NaN
# 76561197964431051                NaN                NaN            1.00000
#
# [1000 rows x 1000 columns]

# %%
u_a_df
# Out:
# app_id             70       240      420      620      2870     4000     \
# author.steamid
# 76561197960269230      1.0      NaN      NaN      NaN      NaN      NaN
# 76561197960269294      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960269409      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960270613      NaN      1.0      NaN      NaN      NaN      NaN
# 76561197960271099      NaN      NaN      NaN      1.0      NaN      NaN
# ...                    ...      ...      ...      ...      ...      ...
# 76561199102337393      NaN      1.0      NaN      NaN      NaN      NaN
# 76561199102458560      NaN      NaN      NaN      NaN      NaN      NaN
# 76561199103154460      NaN      NaN      NaN      NaN      NaN      NaN
# 76561199104605332      NaN      1.0      NaN      1.0      NaN      1.0
# 76561199123615015      NaN      NaN      NaN      NaN      NaN      NaN
#
# app_id             7510     8870     8930     32470    ...  1158310  1170880  \
# author.steamid                                         ...
# 76561197960269230      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960269294      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960269409      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960270613      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960271099      NaN      NaN      NaN      NaN  ...      NaN      NaN
# ...                    ...      ...      ...      ...  ...      ...      ...
# 76561199102337393      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561199102458560      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561199103154460      NaN      1.0      NaN      NaN  ...      NaN      NaN
# 76561199104605332      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561199123615015      NaN      NaN      NaN      NaN  ...      NaN      NaN
#
# app_id             1180380  1190460  1222700  1225330  1229490  1240210  \
# author.steamid
# 76561197960269230      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960269294      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960269409      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960270613      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960271099      NaN      NaN      NaN      NaN      NaN      NaN
# ...                    ...      ...      ...      ...      ...      ...
# 76561199102337393      NaN      NaN      NaN      NaN      NaN      NaN
# 76561199102458560      NaN      1.0      NaN      NaN      NaN      NaN
# 76561199103154460      NaN      NaN      NaN      NaN      NaN      NaN
# 76561199104605332      NaN      NaN      NaN      NaN      NaN      NaN
# 76561199123615015      NaN      NaN      NaN      NaN      NaN      NaN
#
# app_id             1289310  1291340
# author.steamid
# 76561197960269230      NaN      NaN
# 76561197960269294      NaN      NaN
# 76561197960269409      NaN      NaN
# 76561197960270613      NaN      NaN
# 76561197960271099      NaN      NaN
# ...                    ...      ...
# 76561199102337393      NaN      NaN
# 76561199102458560      NaN      NaN
# 76561199103154460      NaN      NaN
# 76561199104605332      NaN      NaN
# 76561199123615015      NaN      NaN
#
# [119484 rows x 315 columns]

# %%
target = u_a_df.loc[76561197960269294]
corr = u_a_df.corrwith(target,axis=1,method='kendall').to_numpy()

# %%
print(target.to_numpy())
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   1. nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan  1. nan nan  1. nan  1. nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan  1. nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan  1. nan nan nan nan nan nan nan  1.
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan  1. nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan  1. nan nan nan nan nan nan nan  1. nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan  1. nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan  1. nan
#  nan nan nan nan nan nan nan nan nan]

# %%
# prompt: 查看coor中有多少个值不是空值

np.count_nonzero(~np.isnan(corr))
# Out:
# 0

# %%
df_reviews = pd.read_csv("drive/MyDrive/9727/steam_reviews_sampled.csv")

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
class User():
  def __init__(self, user_id):
    self.user_id = user_id
    self.recommendations = []
    # Generate users-items matrix
    if user_id == 1:
      self.cold_start()
    else:
      self.u_a_df = df_reviews.pivot_table(index='author.steamid', columns='app_id', values='recommended')
      self.reviewed_games_ids = set(u_a_df.loc[user_id, u_a_df.columns[~u_a_df.loc[user_id].isna()]].index.tolist())

    # dynamic
    self.buffer = []

    # Intialize interest and rating matrix
    self.interest_matrix = self.u_a_df.replace(0, -1)
    self.interest_matrix = self.interest_matrix.fillna(0)
    self.rating_matrix = self.u_a_df.replace(0, -1)
    self.rating_matrix = self.rating_matrix.fillna(0)

  def cold_start(self):
    self.u_a_df = df_reviews.pivot_table(index='author.steamid', columns='app_id', values='recommended')
    self.u_a_df.loc[1] = [np.nan] * len(u_a_df.columns)
    self.reviewed_games_ids = []

  def similarity(self):
    interest_matrix = self.interest_matrix
    sim_matrix = self.cosine(interest_matrix)
    sorted_df = sim_matrix.sort_values(by='Similarity', axis=1, ascending=False)
    return sorted_df

  def cosine(self, matrix):
    uid = self.user_id
    target_user_ratings = matrix.loc[uid].to_frame().T
    similarity_scores = cosine_similarity(target_user_ratings, matrix)
    similarity_df = pd.DataFrame(similarity_scores, columns=matrix.index, index=['Similarity'])
    return similarity_df

  def comment(self, aid):
    if aid in self.reviewed_games_ids:
      return
    self.buffer.append(aid)

  def update_profile(self):
    uid = self.user_id
    self.reviewed_games_ids.extend(self.buffer)
    for aid in self.buffer:
      self.interest_matrix.loc[uid][aid] = 1
      self.rating_matrix.loc[uid][aid] = 1
    self.buffer = []

  def run_model_cf(self):

    self.update_profile()

    # Predict rating by 5 similar users
    similar_users = self.similarity()
    ratings = []
    app_list = u_a_df.columns.tolist()
    for aid in app_list:
      if aid in self.reviewed_games_ids:
        continue
      count = 0
      up = 0
      down = 0
      user_list = similar_users.columns.tolist()[1:]
      for uid in user_list:
        if count == 5:
          break

        rating = self.rating_matrix.loc[uid][aid]

        if rating == 0 or uid == self.user_id:
          continue

        count += 1
        up += similar_users.iloc[0][uid] * rating * self.credibility(uid, aid)
        down += similar_users.iloc[0][uid] * self.credibility(uid, aid)

      final_rating = up / down
      ratings.append((final_rating, aid))

    ratings.sort()
    self.recommendations = [v for _, v in ratings]

    return self.recommendations


  def credibility(self, user_id, app_id):
    df = df_reviews

    def rank(sorted_list, value):
      # bisect_left function returns the index of the inserted value, which is the point that can be inserted while keeping the list sorted
      index = bisect.bisect_left(sorted_list, value)
      # Check if the index is in the range of the list and if the value of the list at the index is equal to the value we are looking for
      if index != len(sorted_list) and sorted_list[index] == value:
        return index + 1
      return -1

    def give_vote_score():
      vote_helpful = df.loc[(df['author.steamid'] == user_id) & (df['app_id'] == app_id), 'votes_helpful'].values[0]
      vote_funny = df.loc[(df['author.steamid'] == user_id) & (df['app_id'] == app_id), 'votes_funny'].values[0]
      if vote_helpful == 0:
        vote_score = 1
      elif 0 < vote_helpful < 10:
        vote_score = 2
      elif 10 <= vote_helpful < 50:
        vote_score = 3
      elif 50 <= vote_helpful < 100:
        vote_score = 4
      elif vote_helpful >= 100:
        vote_score = 5
      if vote_funny >= 10:
        vote_score += 1
      return vote_score

    def give_time_score():
      play_time = df.loc[(df['author.steamid'] == user_id) & (df['app_id'] == app_id), 'author.playtime_at_review'].values[0]
      if play_time < 100:
        time_score = 1
      elif 100 <= play_time < 500:
        time_score = 2
      elif 500 <= play_time < 1000:
        time_score = 3
      elif play_time >= 1000:
        time_score = 4
      elif np.isnan(play_time):
        time_score = 0.1

      return time_score

    # Base score
    Base_score = give_vote_score() + give_time_score()
    # timestamp_updated
    timestamp = df.loc[df['app_id'] == app_id, 'timestamp_updated'].sort_values().values.tolist()
      # Bigger timestamp implies newer review
    user_timestamp = df.loc[(df['app_id'] == app_id) & (df['author.steamid'] == user_id), 'timestamp_updated'].values[0]
    rank = rank(timestamp, user_timestamp)
    newest_per = rank / len(timestamp)
    score = Base_score * newest_per
    # steam_purchase
    if df.loc[(df['author.steamid'] == user_id) & (df['app_id'] == app_id), 'steam_purchase'].values[0] == False:
      score *= 0.5
    # written_during_early_access
    if df.loc[(df['author.steamid'] == user_id) & (df['app_id'] == app_id), 'written_during_early_access'].values[0] == True:
      score *= 0.5

    return round(score, 2)

# %%
user = User(76561197960269294)

# %%
user.run_model_cf()
# Out:
# [334040,
#  1015500,
#  1128000,
#  1180380,
#  619080,
#  247730,
#  688130,
#  489940,
#  236510,
#  285190,
#  583950,
#  282560,
#  841370,
#  681660,
#  428690,
#  510510,
#  817130,
#  272270,
#  1056960,
#  7510,
#  427290,
#  792990,
#  788260,
#  390340,
#  577800,
#  644930,
#  268910,
#  262060,
#  420290,
#  551730,
#  454200,
#  812140,
#  606280,
#  671440,
#  355790,
#  541210,
#  543460,
#  1225330,
#  723390,
#  629910,
#  620980,
#  377160,
#  495560,
#  872790,
#  578080,
#  40800,
#  113200,
#  666140,
#  346110,
#  686600,
#  236850,
#  283640,
#  364360,
#  730310,
#  382310,
#  530070,
#  671510,
#  2870,
#  858210,
#  698780,
#  242760,
#  544750,
#  247240,
#  712100,
#  677160,
#  481510,
#  306130,
#  476600,
#  485510,
#  613830,
#  513710,
#  288160,
#  823130,
#  271590,
#  292730,
#  400940,
#  640820,
#  701160,
#  631510,
#  275850,
#  517630,
#  728880,
#  421020,
#  242920,
#  289070,
#  535930,
#  240720,
#  435150,
#  543900,
#  206440,
#  297130,
#  582660,
#  648350,
#  875210,
#  589360,
#  546050,
#  424840,
#  503940,
#  258180,
#  352550,
#  581320,
#  47890,
#  772540,
#  582010,
#  593600,
#  39210,
#  883710,
#  555220,
#  834910,
#  70,
#  240,
#  420,
#  620,
#  4000,
#  8870,
#  8930,
#  32470,
#  35140,
#  48700,
#  55230,
#  72850,
#  105600,
#  200900,
#  203160,
#  204360,
#  205100,
#  206190,
#  207610,
#  212680,
#  213670,
#  214560,
#  214950,
#  218620,
#  219150,
#  219740,
#  221380,
#  221640,
#  225540,
#  227300,
#  233860,
#  238320,
#  238460,
#  239030,
#  239140,
#  250320,
#  250760,
#  250900,
#  252490,
#  252950,
#  253230,
#  264710,
#  269950,
#  270880,
#  274190,
#  275390,
#  281990,
#  284160,
#  286160,
#  291860,
#  292030,
#  294100,
#  304390,
#  311690,
#  312530,
#  312660,
#  322110,
#  322330,
#  323190,
#  332200,
#  337340,
#  339800,
#  341800,
#  356190,
#  357190,
#  359550,
#  362890,
#  367520,
#  374320,
#  379430,
#  379720,
#  381210,
#  385560,
#  391220,
#  391540,
#  393520,
#  394360,
#  405710,
#  412830,
#  413150,
#  413410,
#  413420,
#  417290,
#  418370,
#  420530,
#  425580,
#  427520,
#  428550,
#  431960,
#  433340,
#  440900,
#  445220,
#  447040,
#  447530,
#  457140,
#  460930,
#  464920,
#  466560,
#  477160,
#  489830,
#  493340,
#  501080,
#  502280,
#  502800,
#  504230,
#  508440,
#  512900,
#  518790,
#  519860,
#  524580,
#  526160,
#  526870,
#  527230,
#  531510,
#  537800,
#  546560,
#  548430,
#  552500,
#  552520,
#  560130,
#  569860,
#  570940,
#  571740,
#  572410,
#  574050,
#  582160,
#  583470,
#  585420,
#  588650,
#  590380,
#  594570,
#  594650,
#  595520,
#  598330,
#  609320,
#  611760,
#  613100,
#  619290,
#  620590,
#  621060,
#  626690,
#  629760,
#  632350,
#  636480,
#  637090,
#  637650,
#  637670,
#  638970,
#  644560,
#  646570,
#  646910,
#  673880,
#  673950,
#  677120,
#  683320,
#  690830,
#  696170,
#  704850,
#  731490,
#  732810,
#  736260,
#  743450,
#  748490,
#  753420,
#  753650,
#  758190,
#  760060,
#  773951,
#  779340,
#  782330,
#  787480,
#  787860,
#  814380,
#  825630,
#  857980,
#  863550,
#  899440,
#  945360,
#  960090,
#  1017900,
#  1055540,
#  1057090,
#  1089980,
#  1113000,
#  1118200,
#  1144400,
#  1158310,
#  1170880,
#  1190460,
#  1222700,
#  1229490,
#  1240210,
#  1289310,
#  1291340]

# %%
user = User(1)

# %%
user.comment(334040)
user.comment(1015500)
user.comment(619080)
user.comment(583950)

# %%
user.run_model_cf()
# Out:
# <ipython-input-42-a30c373e67ee>:80: RuntimeWarning: invalid value encountered in double_scalars
#   final_rating = up / down
# [501080,
#  841370,
#  637090,
#  272270,
#  593600,
#  686600,
#  390340,
#  427290,
#  1056960,
#  578080,
#  577800,
#  464920,
#  1180380,
#  543900,
#  264710,
#  271590,
#  666140,
#  526160,
#  225540,
#  417290,
#  268500,
#  543460,
#  297130,
#  671510,
#  1128000,
#  359550,
#  381210,
#  857980,
#  397540,
#  418370,
#  524220,
#  773951,
#  236510,
#  613100,
#  834910,
#  7510,
#  221380,
#  517630,
#  312530,
#  476600,
#  429660,
#  683320,
#  544750,
#  379430,
#  782330,
#  377160,
#  582660,
#  1225330,
#  872790,
#  696170,
#  551730,
#  447040,
#  626690,
#  252950,
#  435150,
#  379720,
#  282560,
#  730310,
#  238320,
#  454200,
#  595520,
#  239030,
#  2870,
#  420290,
#  433340,
#  352550,
#  424840,
#  594570,
#  460930,
#  875210,
#  113200,
#  788260,
#  1190460,
#  779340,
#  72850,
#  274190,
#  269950,
#  236850,
#  731490,
#  218620,
#  621060,
#  723390,
#  357190,
#  629910,
#  583470,
#  258180,
#  673880,
#  428550,
#  582160,
#  206190,
#  466560,
#  385560,
#  681660,
#  346110,
#  677160,
#  291860,
#  292730,
#  285190,
#  701160,
#  678950,
#  772540,
#  107410,
#  598330,
#  312660,
#  760060,
#  39210,
#  574050,
#  712100,
#  572410,
#  262060,
#  513710,
#  364360,
#  899440,
#  477160,
#  355790,
#  631510,
#  221640,
#  758190,
#  275390,
#  646910,
#  594650,
#  582010,
#  367520,
#  1017900,
#  240720,
#  518790,
#  489830,
#  242760,
#  247730,
#  400940,
#  690830,
#  447820,
#  1057090,
#  546050,
#  428690,
#  728880,
#  688130,
#  502280,
#  70,
#  240,
#  420,
#  620,
#  4000,
#  8870,
#  8930,
#  32470,
#  35140,
#  40800,
#  47890,
#  48700,
#  55230,
#  105600,
#  200900,
#  203160,
#  204360,
#  205100,
#  206440,
#  207610,
#  212680,
#  213670,
#  214560,
#  214950,
#  219150,
#  219740,
#  227300,
#  233860,
#  238460,
#  239140,
#  242920,
#  247240,
#  250320,
#  250760,
#  250900,
#  252490,
#  253230,
#  255710,
#  264200,
#  268910,
#  270880,
#  275850,
#  281990,
#  283640,
#  284160,
#  286160,
#  288160,
#  289070,
#  292030,
#  294100,
#  304390,
#  306130,
#  311690,
#  322110,
#  322330,
#  323190,
#  332200,
#  337340,
#  339800,
#  341800,
#  356190,
#  362890,
#  374320,
#  382310,
#  391220,
#  391540,
#  393520,
#  394360,
#  405710,
#  412830,
#  413150,
#  413410,
#  413420,
#  420530,
#  421020,
#  425580,
#  427520,
#  431960,
#  440900,
#  445220,
#  447530,
#  457140,
#  481510,
#  485510,
#  489940,
#  493340,
#  495560,
#  502800,
#  503940,
#  504230,
#  508440,
#  510510,
#  512900,
#  519860,
#  524580,
#  526870,
#  527230,
#  530070,
#  531510,
#  535930,
#  537800,
#  541210,
#  546560,
#  548430,
#  552500,
#  552520,
#  555220,
#  560130,
#  569860,
#  570940,
#  571740,
#  581320,
#  585420,
#  588650,
#  589360,
#  590380,
#  606280,
#  609320,
#  611760,
#  613830,
#  619290,
#  620590,
#  620980,
#  629760,
#  632350,
#  636480,
#  637650,
#  637670,
#  638970,
#  640820,
#  644560,
#  644930,
#  646570,
#  648350,
#  648800,
#  671440,
#  673950,
#  677120,
#  698780,
#  704850,
#  732810,
#  736260,
#  739630,
#  743450,
#  748490,
#  753420,
#  753650,
#  787480,
#  787860,
#  792990,
#  812140,
#  814380,
#  817130,
#  823130,
#  825630,
#  858210,
#  863550,
#  883710,
#  945360,
#  960090,
#  1055540,
#  1089980,
#  1113000,
#  1118200,
#  1144400,
#  1145360,
#  1158310,
#  1170880,
#  1222700,
#  1229490,
#  1240210,
#  1289310,
#  1291340]
