# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("steam_reviews.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'app_id', 'app_name', 'review_id', 'language',
#        'timestamp_created', 'timestamp_updated', 'recommended',
#        'votes_helpful', 'votes_funny', 'weighted_vote_score', 'comment_count',
#        'steam_purchase', 'received_for_free', 'written_during_early_access',
#        'author.steamid', 'author.num_games_owned', 'author.num_reviews',
#        'author.playtime_forever', 'author.playtime_last_two_weeks',
#        'author.playtime_at_review', 'author.last_played', 'id'],
#       dtype='object')

# %%
df['author.steamid'].nunique()
# Out:
# 12406560

# %%
# Count number of reviews for each user
df_count = df['author.steamid'].value_counts().to_frame().reset_index().rename(columns={'author.steamid': 'count'})

# %%
df_count.query("count >= 10")
# Out:
#                     index  count
# 0       76561198062813911    149
# 1       76561198315585536    132
# 2       76561198192166873    107
# 3       76561198239163744    106
# 4       76561198045381877    103
# ...                   ...    ...
# 119479  76561198134530251     10
# 119480  76561197982171292     10
# 119481  76561198189593293     10
# 119482  76561198255402392     10
# 119483  76561198068439332     10
#
# [119484 rows x 2 columns]

# %%
# Sampling: only reserve users who made more than 10 reviews
new_df = df.loc[df['author.steamid'].isin(df_count.query("count >= 10")['index'].values), :]

# %%
new_df.shape
# Out:
# (1693064, 23)

# %%
# Generate users-items matrix
u_a_df = new_df.pivot_table(index='author.steamid', columns='app_id', values='recommended')

# %%
u_a_df.head()
# Out:
# app_id             70       240      420      620      2870     4000     \
# author.steamid
# 76561197960269230      1.0      NaN      NaN      NaN      NaN      NaN
# 76561197960269294      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960269409      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960270613      NaN      1.0      NaN      NaN      NaN      NaN
# 76561197960271099      NaN      NaN      NaN      1.0      NaN      NaN
#
# app_id             7510     8870     8930     32470    ...  1158310  1170880  \
# author.steamid                                         ...
# 76561197960269230      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960269294      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960269409      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960270613      NaN      NaN      NaN      NaN  ...      NaN      NaN
# 76561197960271099      NaN      NaN      NaN      NaN  ...      NaN      NaN
#
# app_id             1180380  1190460  1222700  1225330  1229490  1240210  \
# author.steamid
# 76561197960269230      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960269294      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960269409      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960270613      NaN      NaN      NaN      NaN      NaN      NaN
# 76561197960271099      NaN      NaN      NaN      NaN      NaN      NaN
#
# app_id             1289310  1291340
# author.steamid
# 76561197960269230      NaN      NaN
# 76561197960269294      NaN      NaN
# 76561197960269409      NaN      NaN
# 76561197960270613      NaN      NaN
# 76561197960271099      NaN      NaN
#
# [5 rows x 315 columns]

# %%
new_df.loc[df['author.steamid'] == 76561198062813911, :]
# Out:
#           Unnamed: 0  app_id                  app_name  review_id language  \
# 512675        512676      70                 Half-Life   29251440  english
# 539037        539038     240    Counter-Strike: Source   71899643  english
# 658130        658131     420  Half-Life 2: Episode Two   37036842  english
# 849477        849478     620                  Portal 2   17866117  english
# 1549581      1549582    4000               Garry's Mod    6281334  english
# ...              ...     ...                       ...        ...      ...
# 21578107    21578112  367520             Hollow Knight   44704056  english
# 21624890    21624895  447820             Day of Infamy   32070388  english
# 21651066    21651071  598330                SimAirport   30840789  english
# 21656340    21656345  543460             Dead Rising 4   68516852  english
# 21672218    21672223  355790  Styx: Shards of Darkness   35024623  english
#
#           timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 512675           1484411669         1484411669         True              0
# 539037           1593717565         1593717565         True              0
# 658130           1511438724         1511438744         True              1
# 849477           1441305015         1441305258         True              0
# 1549581          1374488725         1418986129         True              1
# ...                     ...                ...          ...            ...
# 21578107         1536788275         1536788275         True              0
# 21624890         1496174428         1496174428         True              0
# 21651066         1490906109         1490906109         True              0
# 21656340         1588540484         1588540491         True              1
# 21672218         1505657932         1511430359         True             11
#
#           votes_funny  ...  received_for_free  written_during_early_access  \
# 512675              0  ...              False                        False
# 539037              0  ...              False                        False
# 658130              0  ...              False                        False
# 849477              0  ...              False                        False
# 1549581             0  ...              False                        False
# ...               ...  ...                ...                          ...
# 21578107            0  ...              False                        False
# 21624890            0  ...              False                        False
# 21651066            0  ...              False                         True
# 21656340            0  ...              False                        False
# 21672218            2  ...              False                        False
#
#              author.steamid  author.num_games_owned  author.num_reviews  \
# 512675    76561198062813911                    1584                1621
# 539037    76561198062813911                    1584                1621
# 658130    76561198062813911                    1584                1621
# 849477    76561198062813911                    1584                1621
# 1549581   76561198062813911                    1584                1621
# ...                     ...                     ...                 ...
# 21578107  76561198062813911                    1584                1621
# 21624890  76561198062813911                    1584                1621
# 21651066  76561198062813911                    1584                1621
# 21656340  76561198062813911                    1584                1621
# 21672218  76561198062813911                    1584                1621
#
#           author.playtime_forever  author.playtime_last_two_weeks  \
# 512675                      792.0                             0.0
# 539037                      370.0                             0.0
# 658130                      260.0                             0.0
# 849477                      392.0                             0.0
# 1549581                    2647.0                             0.0
# ...                           ...                             ...
# 21578107                    209.0                             0.0
# 21624890                    581.0                             0.0
# 21651066                   2844.0                             1.0
# 21656340                    626.0                             0.0
# 21672218                    764.0                             0.0
#
#           author.playtime_at_review  author.last_played      id
# 512675                        790.0        1.520431e+09      70
# 539037                        370.0        1.593717e+09     240
# 658130                        260.0        1.511436e+09     420
# 849477                        392.0        1.441297e+09     620
# 1549581                      2429.0        1.419871e+09    4000
# ...                             ...                 ...     ...
# 21578107                      209.0        1.536247e+09  367520
# 21624890                      581.0        1.496174e+09  447820
# 21651066                      958.0        1.610829e+09  598330
# 21656340                      626.0        1.588522e+09  543460
# 21672218                      764.0        1.505657e+09  355790
#
# [149 rows x 23 columns]

# %%
new_df.loc[(new_df['steam_purchase'] == True) & (new_df['received_for_free'] == True), :].head(3)
# Out:
#        Unnamed: 0  app_id                  app_name  review_id  language  \
# 12084       12084  292030  The Witcher 3: Wild Hunt   83324961   english
# 13718       13718  292030  The Witcher 3: Wild Hunt   83103321   russian
# 17615       17615  292030  The Witcher 3: Wild Hunt   82542331  schinese
#
#        timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 12084         1609099045         1609099045         True              0
# 13718         1608892460         1608892460         True              1
# 17615         1608186554         1608186554         True            972
#
#        votes_funny  ...  received_for_free  written_during_early_access  \
# 12084            2  ...               True                        False
# 13718            1  ...               True                        False
# 17615           71  ...               True                        False
#
#           author.steamid  author.num_games_owned  author.num_reviews  \
# 12084  76561198302463343                      28                  23
# 13718  76561198052888970                      72                  67
# 17615  76561198240308814                     191                  33
#
#        author.playtime_forever  author.playtime_last_two_weeks  \
# 12084                    331.0                             0.0
# 13718                    447.0                            53.0
# 17615                    696.0                             0.0
#
#        author.playtime_at_review  author.last_played      id
# 12084                      126.0        1.609274e+09  292030
# 13718                      206.0        1.611118e+09  292030
# 17615                      696.0        1.591345e+09  292030
#
# [3 rows x 23 columns]

# %%
new_df.loc[(new_df['steam_purchase'] == True) & (new_df['received_for_free'] == False), :].head(3)
# Out:
#     Unnamed: 0  app_id                  app_name  review_id  language  \
# 39          39  292030  The Witcher 3: Wild Hunt   85174926   english
# 47          47  292030  The Witcher 3: Wild Hunt   85172618   turkish
# 76          76  292030  The Witcher 3: Wild Hunt   85165570  schinese
#
#     timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 39         1611364401         1611364470         True              0
# 47         1611360594         1611360594         True              0
# 76         1611350390         1611350390         True              0
#
#     votes_funny  ...  received_for_free  written_during_early_access  \
# 39            0  ...              False                        False
# 47            0  ...              False                        False
# 76            0  ...              False                        False
#
#        author.steamid  author.num_games_owned  author.num_reviews  \
# 39  76561198020027165                     208                 105
# 47  76561198246626952                     206                  26
# 76  76561198220195440                     168                  56
#
#     author.playtime_forever  author.playtime_last_two_weeks  \
# 39                    497.0                           370.0
# 47                   3929.0                            41.0
# 76                   4988.0                           250.0
#
#     author.playtime_at_review  author.last_played      id
# 39                      398.0        1.611370e+09  292030
# 47                     3929.0        1.610813e+09  292030
# 76                     4737.0        1.611367e+09  292030
#
# [3 rows x 23 columns]

# %%
new_df.loc[(new_df['steam_purchase'] == False) & (new_df['received_for_free'] == True), :].head(3)
# Out:
#       Unnamed: 0  app_id                  app_name  review_id language  \
# 4129        4129  292030  The Witcher 3: Wild Hunt   84447402  russian
# 4949        4949  292030  The Witcher 3: Wild Hunt   84330747  russian
# 7510        7510  292030  The Witcher 3: Wild Hunt   83968159  russian
#
#       timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 4129         1610305316         1610305316        False              5
# 4949         1610159686         1610159686         True              1
# 7510         1609743028         1609743028         True              0
#
#       votes_funny  ...  received_for_free  written_during_early_access  \
# 4129            0  ...               True                        False
# 4949            0  ...               True                        False
# 7510            0  ...               True                        False
#
#          author.steamid  author.num_games_owned  author.num_reviews  \
# 4129  76561198253363352                     268                 101
# 4949  76561198398141804                      33                  12
# 7510  76561198306008357                      68                  36
#
#       author.playtime_forever  author.playtime_last_two_weeks  \
# 4129                    160.0                             0.0
# 4949                  10253.0                          5429.0
# 7510                   6208.0                          1255.0
#
#       author.playtime_at_review  author.last_played      id
# 4129                      160.0        1.607953e+09  292030
# 4949                     4504.0        1.611308e+09  292030
# 7510                     3982.0        1.610652e+09  292030
#
# [3 rows x 23 columns]

# %%
new_df.loc[(new_df['steam_purchase'] == False) & (new_df['received_for_free'] == False), :].head(3)
# Out:
#      Unnamed: 0  app_id                  app_name  review_id  language  \
# 41           41  292030  The Witcher 3: Wild Hunt   85173767   turkish
# 146         146  292030  The Witcher 3: Wild Hunt   85153647   russian
# 321         321  292030  The Witcher 3: Wild Hunt   85122164  schinese
#
#      timestamp_created  timestamp_updated  recommended  votes_helpful  \
# 41          1611362536         1611364881         True              0
# 146         1611335171         1611335171        False              1
# 321         1611286912         1611286912         True              0
#
#      votes_funny  ...  received_for_free  written_during_early_access  \
# 41             0  ...              False                        False
# 146            0  ...              False                        False
# 321            0  ...              False                        False
#
#         author.steamid  author.num_games_owned  author.num_reviews  \
# 41   76561198316530785                     217                  34
# 146  76561198344619208                      70                  24
# 321  76561198277218887                     272                  18
#
#      author.playtime_forever  author.playtime_last_two_weeks  \
# 41                    6841.0                          2077.0
# 146                    279.0                           135.0
# 321                    682.0                             0.0
#
#      author.playtime_at_review  author.last_played      id
# 41                      6841.0        1.611364e+09  292030
# 146                      261.0        1.611336e+09  292030
# 321                      682.0        1.607052e+09  292030
#
# [3 rows x 23 columns]

# %%
# credibility : {timestamp_updated: Review latest update timestamp
#         votes_helpful: Number of "helpful" votes for review
#         votes_funny: Number of "funny" votes for review
#         steam_purchase: Whether review author purchased the app on Steam
#         written_during_early_access: Whether review was written during early access
#         author.playtime_at_review: Author playtime of reviewed app at time of review}

# %%
import bisect


def credibility(user_id, app_id, df):
    def rank(sorted_list, value):
        # bisect_left function returns the index of the inserted value, which is the point that can be inserted while keeping the list sorted
        index = bisect.bisect_left(sorted_list, value)
        # Check if the index is in the range of the list and if the value of the list at the index is equal to the value we are looking for
        if index != len(sorted_list) and sorted_list[index] == value:
            return index + 1
        return -1

    def give_vote_score():
        vote_helpful = df.loc[
            (df["author.steamid"] == user_id) & (df["app_id"] == app_id),
            "votes_helpful",
        ].values[0]
        vote_funny = df.loc[
            (df["author.steamid"] == user_id) & (df["app_id"] == app_id), "votes_funny"
        ].values[0]
        if vote_helpful == 0:
            vote_score = 1
        elif 0 < vote_helpful < 10:
            vote_score = 2
        elif 10 <= vote_helpful < 50:
            vote_score = 3
        elif 50 <= vote_helpful < 100:
            vote_score = 4
        elif vote_helpful >= 100:
            vote_score = 5
        if vote_funny >= 10:
            vote_score += 1
        return vote_score

    def give_time_score():
        play_time = df.loc[
            (df["author.steamid"] == user_id) & (df["app_id"] == app_id),
            "author.playtime_at_review",
        ].values[0]
        if play_time < 100:
            time_score = 1
        elif 100 <= play_time < 500:
            time_score = 2
        elif 500 <= play_time < 1000:
            time_score = 3
        elif play_time >= 1000:
            time_score = 4
        return time_score

    # Base score
    Base_score = give_vote_score() + give_time_score()
    print(Base_score)
    # timestamp_updated
    timestamp = (
        df.loc[df["app_id"] == app_id, "timestamp_updated"]
        .sort_values()
        .values.tolist()
    )
    # Bigger timestamp implies newer review
    user_timestamp = df.loc[
        (df["app_id"] == app_id) & (df["author.steamid"] == user_id),
        "timestamp_updated",
    ].values[0]
    rank = rank(timestamp, user_timestamp)
    newest_per = rank / len(timestamp)
    score = Base_score * newest_per
    # steam_purchase
    if (
        df.loc[
            (df["author.steamid"] == user_id) & (df["app_id"] == app_id),
            "steam_purchase",
        ].values[0]
        == False
    ):
        score *= 0.5
    # written_during_early_access
    if (
        df.loc[
            (df["author.steamid"] == user_id) & (df["app_id"] == app_id),
            "written_during_early_access",
        ].values[0]
        == True
    ):
        score *= 0.5

    return round(score, 2)

# %%
# cosine 1.0
modified_df = u_a_df.replace(0, -1)
modified_df = modified_df.fillna(0)

# %%
# cosine 2.0
modified_df = u_a_df.replace(0, 1)
modified_df = modified_df.fillna(0)

# %%
from sklearn.metrics.pairwise import cosine_similarity
'''
compute the similarity of uid and other users.
return dataFrame (index = uid)
certified cosine similarity. 
0 -> -1;
NaN -> 0;
1 -> 1;

or

0, 1 -> 1
NaN -> 0

'''

def cosine(matrix, uid):
    target_user_ratings = matrix.loc[uid].to_frame().T
    similarity_scores = cosine_similarity(target_user_ratings, matrix)
    similarity_df = pd.DataFrame(similarity_scores, columns=matrix.index, index=['Similarity'])
    return similarity_df

# %%
result = cosine(modified_df, "uid")

# %%
sorted_df = result.sort_values(by='Similarity', axis=1)
sorted_df

# %%
# test
def test_accuracy(targetId, df, similarity_matrix):
    target = df.loc[targetId].to_numpy()
    arr = list(similarity_matrix.columns)
    for j in range(0, len(arr), 1200):
        id = arr[j]
        test = df.loc[id].to_numpy()
        n = 0
        for i in range(315):
            if target[i] == test[i] and (target[i] != 0 or target[i] != None):
                n += 1
        print(n, end=" ")

test_accuracy(76561197960270613, u_a_df, sorted_df)

# %%
def predict(uid, iid, matrix, n=1000):
    all_user_sim = cosine(matrix, uid).sort_values(by='Similarity', axis=1, ascending=False)
    top_user_sim = all_user_sim.drop(all_user_sim.columns[all_user_sim > n])

# %%
predict(76561197960269294, "70", modified_df)
